# %% [markdown]
# # Linear regression by using Deep Neural network: Implement Boston housing price  prediction problem by Linear regression using Deep Neural network.
# Use Boston House price prediction dataset

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow.keras import Sequential 
from tensorflow.keras.layers import Dense,Dropout

# %%
df=pd.read_csv("boston.csv")
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90   5.33  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT        MEDV
# count  506.000000  506.000000
# mean    12.653063   22.532806
# std      7.141062    9.197104
# min      1.730000    5.000000
# 25%      6.950000   17.025000
# 50%     11.360000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %%
df.size
# Out:
# 7084

# %%
df.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
df.dtypes
# Out:
# CRIM       float64
# ZN         float64
# INDUS      float64
# CHAS         int64
# NOX        float64
# RM         float64
# AGE        float64
# DIS        float64
# RAD          int64
# TAX        float64
# PTRATIO    float64
# B          float64
# LSTAT      float64
# MEDV       float64
# dtype: object

# %%
x=df.drop(["MEDV"] ,axis=1)
y=df["MEDV"]

# %%
#split into training data and testing data 
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
#build Deep Learning Model with extra dense and dropout layers 
model = Sequential([
    Dense(64, activation='relu', input_shape=(x_train.shape[1],)),
    Dense(64, activation='relu'),
    Dense(1)  # Linear activation by default
])
model.compile(optimizer='adam', loss='mse', metrics=['mae'])
# Out:
# C:\Users\Admin\anaconda3\envs\tf_env\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
#Train the model
model.fit(x_train,y_train,epochs=100,batch_size=16,verbose=1)
# Out:
# Epoch 1/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 184.5502 - mae: 11.0496
# Epoch 2/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 64.3705 - mae: 5.8106
# Epoch 3/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 94.0045 - mae: 7.3407
# Epoch 4/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 85.4732 - mae: 7.0244
# Epoch 5/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 61.5802 - mae: 5.4186
# Epoch 6/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 60.4860 - mae: 5.6063
# Epoch 7/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 50.3740 - mae: 5.2351
# Epoch 8/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 76.6034 - mae: 6.6606
# Epoch 9/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 68.7282 - mae: 6.4300
# Epoch 10/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 58.4258 - mae: 5.7077
# Epoch 11/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 49.9113 - mae: 5.2694
# Epoch 12/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 45.1122 - mae: 4.7640
# Epoch 13/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 49.9011 - mae: 5.1432
# Epoch 14/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 36.8237 - mae: 4.5410
# Epoch 15/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 44.0088 - mae: 4.8734
# Epoch 16/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 38.0282 - mae: 4.6432
# Epoch 17/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 81.6832 - mae: 6.9158
# Epoch 18/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 35.0901 - mae: 4.3464
# Epoch 19/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 45.4850 - mae: 4.8762
# Epoch 20/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 29.3057 - mae: 3.9469
# Epoch 21/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 32.4464 - mae: 4.3158
# Epoch 22/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 32.8673 - mae: 4.2175
# Epoch 23/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 51.6781 - mae: 5.1885
# Epoch 24/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 32.1029 - mae: 4.1725
# Epoch 25/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 36.2866 - mae: 4.6175
# Epoch 26/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 33.0778 - mae: 4.2399
# Epoch 27/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 34.1719 - mae: 4.2830
# Epoch 28/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 42.2620 - mae: 4.7680
# Epoch 29/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 48.3627 - mae: 5.2709
# Epoch 30/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 30.7023 - mae: 3.9111
# Epoch 31/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 38.9943 - mae: 4.7823
# Epoch 32/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 32.2860 - mae: 4.2435
# Epoch 33/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 37.7826 - mae: 4.8513
# Epoch 34/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 31.8564 - mae: 4.2448
# Epoch 35/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 32.4187 - mae: 4.3156
# Epoch 36/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 38.8082 - mae: 4.8589
# Epoch 37/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 31.3468 - mae: 4.2028
# Epoch 38/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 32.6097 - mae: 4.2560
# Epoch 39/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 30.0722 - mae: 4.1789
# Epoch 40/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 23.1373 - mae: 3.6006
# Epoch 41/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 27.8515 - mae: 4.0968
# Epoch 42/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 32.0763 - mae: 4.3100
# Epoch 43/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 26.3573 - mae: 3.8920
# Epoch 44/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 26.6047 - mae: 3.8009
# Epoch 45/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 28.4083 - mae: 3.8113
# Epoch 46/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 29.3061 - mae: 4.1525
# Epoch 47/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 26.9437 - mae: 3.8842
# Epoch 48/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 28.8268 - mae: 4.3035
# Epoch 49/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 38.4818 - mae: 4.9322
# Epoch 50/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 49.0570 - mae: 5.5510
# Epoch 51/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 34.0217 - mae: 4.5967
# Epoch 52/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 29.7030 - mae: 3.9979
# Epoch 53/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 28.7213 - mae: 3.8798
# Epoch 54/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 25.6342 - mae: 3.6433
# Epoch 55/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 25.8947 - mae: 3.6400
# Epoch 56/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 29.8733 - mae: 4.0813
# Epoch 57/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 35.8430 - mae: 4.6189
# Epoch 58/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 24.7356 - mae: 3.7026
# Epoch 59/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 25.6612 - mae: 3.8359
# Epoch 60/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 23.5316 - mae: 3.5219
# Epoch 61/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 27.4235 - mae: 3.8419
# Epoch 62/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 22.6624 - mae: 3.5336
# Epoch 63/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 23.6139 - mae: 3.6031
# Epoch 64/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 25.2160 - mae: 3.7693
# Epoch 65/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 28.8289 - mae: 4.1915
# Epoch 66/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 35.9497 - mae: 4.8576
# Epoch 67/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 39.6557 - mae: 4.9173
# Epoch 68/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 31.9582 - mae: 4.3424
# Epoch 69/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 27.4658 - mae: 4.2576
# Epoch 70/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 28.0721 - mae: 4.1329
# Epoch 71/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 25.1701 - mae: 3.9124
# Epoch 72/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 24.1712 - mae: 3.8458
# Epoch 73/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 25.0762 - mae: 3.7914
# Epoch 74/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 25.0145 - mae: 3.8938
# Epoch 75/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 23.3428 - mae: 3.5948
# Epoch 76/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 33.6994 - mae: 4.5856
# Epoch 77/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 22.6922 - mae: 3.7229
# Epoch 78/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 21.0945 - mae: 3.4207
# Epoch 79/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 23.1465 - mae: 3.8456
# Epoch 80/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 18.9901 - mae: 3.1177
# Epoch 81/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 20.7688 - mae: 3.3980
# Epoch 82/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 34.4300 - mae: 4.7923
# Epoch 83/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 28.1321 - mae: 4.0848
# Epoch 84/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 17.4812 - mae: 3.1421
# Epoch 85/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 23.3739 - mae: 3.7935
# Epoch 86/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 31.2279 - mae: 4.2675
# Epoch 87/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 29.7821 - mae: 4.1469
# Epoch 88/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 14.0785 - mae: 2.8602
# Epoch 89/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 28.5140 - mae: 4.1872
# Epoch 90/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 30.4435 - mae: 4.3911
# Epoch 91/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 22.2510 - mae: 3.6075
# Epoch 92/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 22.3346 - mae: 3.4005
# Epoch 93/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 23.0187 - mae: 3.6546
# Epoch 94/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 22.4753 - mae: 3.6593
# Epoch 95/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 24.5432 - mae: 3.8088
# Epoch 96/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 30.5347 - mae: 4.3798
# Epoch 97/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 20.6079 - mae: 3.4565
# Epoch 98/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 22.4351 - mae: 3.5604
# Epoch 99/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 21.2273 - mae: 3.5155
# Epoch 100/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 17.8983 - mae: 3.2318

# %%
#model Evaluate
loss,mae=model.evaluate(x_test,y_test)
print("Test MSE:",loss)
print("TEST MAE:",mae)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 19.4434 - mae: 3.2166
# Test MSE: 23.657432556152344
# TEST MAE: 3.351823091506958
